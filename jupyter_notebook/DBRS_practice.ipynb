# %%
#cleaning zipcodes practice

import pandas as pd
import numpy as np
from sodapy import Socrata

token = '9EDniwZuIo69m780HXzBZ7oxK'
client = Socrata('data.cityofnewyork.us', token)
results1 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC')
results2 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=500000)
results3 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=1000000)
results4 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=1500000)
results5 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=2000000)

results_df1 = pd.DataFrame.from_records(results1)
results_df2 = pd.DataFrame.from_records(results2)
results_df3 = pd.DataFrame.from_records(results3)
results_df4 = pd.DataFrame.from_records(results4)
results_df5 = pd.DataFrame.from_records(results5)

combined_df = pd.concat([results_df1, results_df2, results_df3, results_df4, results_df5])

#remove short zips and all zero zips
all_zips = combined_df.incident_zip.str.slice(0, 5)
short_zips = all_zips.str.len() < 5
zero_zips = all_zips == '00000'
combined_df[short_zips] = np.nan
combined_df[zero_zips] = np.nan

#remaining zips should all be clean
good_zips = combined_df.incident_zip.str.replace(r'[A-Z /.?]','')
good_zips = good_zips.str.slice(0, 5)
print(good_zips.unique())
# Out:
# ['11234' '11249' '11435' '11372' '11105' '11101' '11207' '10012' '10459'
#  '11206' '10010' '11212' '10455' '11238' '10314' '11225' '11201' '10030'
#  '11233' '10028' '10457' '10003' '11208' '10009' '10301' '11210' '11694'
#  '11418' '10467' '11368' '11209' '10040' '10470' '11217' '11214' '11691'
#  '10305' '10458' '11366' '10460' '11204' '11419' '10312' '11373' '11374'
#  '11215' '11205' '10011' '10033' '11221' '11232' '11229' '10031' '11377'
#  '10472' '10027' '10019' '10304' '10017' '10034' '10032' '11361' '10029'
#  '11222' '11357' '11203' '11417' '11226' '10452' '11427' '10303' '11213'
#  '10038' '10023' '10451' '11223' '10014' '11415' '11236' '10065' '10307'
#  '11432' nan '11106' '11218' '11693' '11370' '11216' '11219' '10453'
#  '10002' '10025' '10016' '11434' '10013' '10454' '10026' '10473' '11235'
#  '10128' '11428' '10469' '11416' '11385' '10468' '10471' '11211' '10039'
#  '11378' '10461' '11692' '10036' '10456' '10463' '11103' '11104' '10024'
#  '10310' '11426' '11355' '11436' '11237' '11102' '10466' '10465' '11358'
#  '10075' '10474' '11421' '10306' '11379' '11369' '11433' '11375' '11420'
#  '11228' '10464' '10462' '11367' '11365' '11220' '11239' '10001' '11230'
#  '11422' '10035' '11231' '11224' '11411' '11354' '10154' '10004' '10018'
#  '11414' '11423' '10021' '11413' '10037' '11356' '10475' '11412' '10302'
#  '11364' '10309' '11001' '10005' '10022' '07114' '11040' '10308' '11429'
#  '11362' '10007' '11363' '10112' '11430' '11004' '10119' '11360' '10280'
#  '10006' '10168' '10282' '42301' '10155' '11791' '11005' '10044' '08876'
#  '10121' '10069' '90054' '19123' '60179' '92131' '10118' '11558' '10041' ''
#  '11706' '12222' '11021' '07090' '91942' '44087' '11793' '11581' '33309'
#  '11109' '07310' '10805' '10271' '10162' '11697' '07094' '11553' '10977'
#  '10173' '11371' '12553' '11561' '10573' '10567' '10545' '11530' '07030'
#  '10174' '10123' '10169' '10110' '10120' '10000' '12205' '02062' '10604'
#  '10279' '11570' '10803' '07640' '11050' '10913' '10105' '07040' '10591'
#  '10178' '10020' '07201' '10106' '19047' '10801' '11518' '10278' '11359'
#  '10701' '11776' '10179' '10165' '10804' '61702' '33134' '11743' '10167'
#  '07013' '11580' '11514' '97062' '11550' '10583' '10176' '10122' '11003'
#  '11510' '10103' '00083' '10111' '11802' '11779' '10153' '11757' '10172'
#  '11695' '11251' '10151' '11803' '19040' '11746' '07103' '11735' '11901'
#  '10166' '11726' '19456' '77272' '07205' '11753' '11722' '10710' '07621'
#  '07105' '30022' '07087' '29615' '11559' '10704' '55343' '14614' '11042'
#  '11242' '10138' '11352' '10281' '11010' '11766' '11973' '11030' '48451'
#  '10580' '11241' '11710' '98036' '02298' '89117' '10152' '10532' '07047'
#  '10101' '11783' '11747' '11501' '07660' '11749' '10107' '32241' '14221'
#  '19007' '32780' '11560' '12550' '07093' '11714' '10158' '06840' '07714'
#  '07601' '11111' '11788' '10533' '07670' '10276' '06901' '10055' '07649'
#  '11720' '23541' '85285' '11020' '07054' '07102' '11552' '07002' '14414'
#  '10601' '85016' '10550' '10070' '91203' '43226' '11933' '07020' '11577'
#  '07078' '10552' '48071' '19713' '10171' '44515' '18773' '11590' '57709'
#  '97526' '06870' '80111' '11717' '06460' '10543' '34987' '10994' '19714'
#  '46219' '10045' '11796' '13350' '64116' '05620' '11563' '11566' '02767'
#  '60197' '17608' '10048' '07648' '11716' '07086' '75007' '08830' '32255'
#  '11797' '11557' '08003' '07302' '08730' '01583' '11096' '65211' '07203'
#  '08817' '18324' '14127' '10501' '91765' '29732' '10159' '10115' '07424'
#  '17055' '32256' '55433' '75403' '10170' '78704' '15129' '10104' '07144'
#  '91716' '11801' '06066' '07024' '11576' '06903' '06810' '10703' '11261'
#  '07069' '08902' '11551' '30066' '12525' '48333' '74612' '11729' '07101'
#  '12771' '30189' '30010' '11516' '10523' '10522' '10553' '10705' '11023'
#  '07306' '60675' '11758' '95035' '07304' '40290' '07656' '12345' '92571'
#  '10538' '07307' '07016' '07663' '11756' '06501' '08854' '23464' '11572'
#  '11755' '10504' '98004' '11542' '23502' '02109' '80401' '12207' '53566'
#  '10536' '28306' '11784' '12250' '10270' '07070' '10549' '97208' '33355'
#  '11520' '32207' '10108' '55164' '10606' '63179' '10401' '06489' '11731'
#  '85201' '08011' '10177' '10426' '07073' '43218' '43236' '07920' '75024'
#  '48083' '10476' '07039' '10750' '10853' '10412' '10707' '60604' '43017'
#  '10952' '07726' '07108' '13903' '10510' '11507' '11794' '07004' '11950'
#  '10956' '07652' '11024' '07010' '12590' '18104' '38655' '14075' '08757'
#  '07657' '11575' '14726' '35244' '10595' '94123' '60173' '33609' '30360'
#  '68501' '06320' '31600' '10590' '08527' '19044' '10514' '10582' '94524'
#  '07666' '07724' '10594' '10530' '34134' '07202' '60077' '30134' '10175'
#  '11704' '11725' '10008' '12189' '16335' '07305' '11702' '07104' '08861'
#  '14225' '07014' '08859' '92108' '11701' '02061' '98335' '08901' '93706'
#  '06830' '11579' '92675' '21201' '33614' '10984' '96056' '13202' '11768'
#  '08840' '06880' '30353' '23450' '10562' '07123' '06855' '11202' '11123'
#  '11408' '10965' '11772' '11795' '06114' '14624' '07052' '11307' '07721'
#  '07960' '07504' '11780' '01757' '11741' '37402' '19850' '44146' '11565'
#  '00711' '10708' '19139' '06820' '10917' '11787' '01234' '07007' '11554'
#  '13601' '11771' '08063' '61367' '14901' '33131' '07604' '07029' '80235'
#  '06831' '30006' '60603' '28901' '37214' '20049' '07111']

# %%
#: unspecified borough type

import pandas as pd
import numpy as np
from sodapy import Socrata

pd.options.display.max_rows = 5000

token = '9EDniwZuIo69m780HXzBZ7oxK'
client = Socrata('data.cityofnewyork.us', token)
results1 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough, city", limit=500000, order='created_date ASC')
results2 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough, city", limit=500000, order='created_date ASC', offset=500000)
results3 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough, city", limit=500000, order='created_date ASC', offset=1000000)
results4 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough, city", limit=500000, order='created_date ASC', offset=1500000)
results5 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough, city", limit=500000, order='created_date ASC', offset=2000000)

results_df1 = pd.DataFrame.from_records(results1)
results_df2 = pd.DataFrame.from_records(results2)
results_df3 = pd.DataFrame.from_records(results3)
results_df4 = pd.DataFrame.from_records(results4)
results_df5 = pd.DataFrame.from_records(results5)

combined_df = pd.concat([results_df1, results_df2, results_df3, results_df4, results_df5])
borough_zip = combined_df[['borough', 'incident_zip', 'city']]
unspecifieds = borough_zip[borough_zip['borough'] == 'Unspecified']
print('Number of Unspecified Boroughs {}'.format(unspecifieds.borough.count()))
print(unspecifieds)

# %%
# Consider only the 10 most common overall complaint types. For each borough, how many of each of those 10 types were there in 2017?

import pandas as pd
import numpy as np
from sodapy import Socrata

pd.options.display.max_rows = 5000

token = '9EDniwZuIo69m780HXzBZ7oxK'
client = Socrata('data.cityofnewyork.us', token)
results1 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC')
results2 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=500000)
results3 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=1000000)
results4 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=1500000)
results5 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=2000000)

results_df1 = pd.DataFrame.from_records(results1)
results_df2 = pd.DataFrame.from_records(results2)
results_df3 = pd.DataFrame.from_records(results3)
results_df4 = pd.DataFrame.from_records(results4)
results_df5 = pd.DataFrame.from_records(results5)

combined_df = pd.concat([results_df1, results_df2, results_df3, results_df4, results_df5])

#: Clean the zip codes
#remove short zips and all zero zips
all_zips = combined_df.incident_zip.str.slice(0, 5)
short_zips = all_zips.str.len() < 5
zero_zips = all_zips == '00000'
combined_df[short_zips] = np.nan
combined_df[zero_zips] = np.nan
#remaining zips should all be clean
good_zips = combined_df.incident_zip.str.replace(r'[A-Z /.?]','')
good_zips = good_zips.str.slice(0, 5)

#: Get the top 10 complaints
all_complaints = combined_df[['complaint_type']]
top_tens = all_complaints.complaint_type.value_counts()[:10]
top_ten = top_tens.to_dict().keys()

complaints_boroughs = combined_df[['complaint_type', 'incident_zip', 'borough']]
top_ten_complaints_by_boroughs = complaints_boroughs[complaints_boroughs.complaint_type.isin(top_ten)]
complaints_count = top_ten_complaints_by_boroughs.groupby('borough').complaint_type.value_counts()
print(complaints_count)
# Out:
# borough        complaint_type
# BRONX          HEAT/HOT WATER             67828
#                Noise - Residential        57420
#                UNSANITARY CONDITION       24530
#                Blocked Driveway           24480
#                Street Light Condition     18408
#                Illegal Parking            16099
#                Noise - Street/Sidewalk    14024
#                Street Condition           11758
#                Water System               10197
#                Noise                       3131
# BROOKLYN       Noise - Residential        67482
#                HEAT/HOT WATER             66079
#                Illegal Parking            55306
#                Blocked Driveway           49154
#                UNSANITARY CONDITION       26636
#                Street Condition           25412
#                Street Light Condition     22447
#                Noise - Street/Sidewalk    21306
#                Water System               19769
#                Noise                      15401
# MANHATTAN      Noise - Residential        50814
#                HEAT/HOT WATER             45931
#                Noise - Street/Sidewalk    29127
#                Noise                      28982
#                Illegal Parking            19669
#                Street Condition           14833
#                UNSANITARY CONDITION       14619
#                Street Light Condition     11073
#                Water System               10897
#                Blocked Driveway            3420
# QUEENS         Blocked Driveway           54142
#                Noise - Residential        46252
#                Illegal Parking            45960
#                Street Condition           30625
#                HEAT/HOT WATER             28870
#                Street Light Condition     24255
#                Water System               18762
#                UNSANITARY CONDITION       11449
#                Noise                      10679
#                Noise - Street/Sidewalk     7526
# STATEN ISLAND  Street Condition           10559
#                Illegal Parking             7574
#                Noise - Residential         6744
#                Street Light Condition      6603
#                Water System                5333
#                Blocked Driveway            3465
#                HEAT/HOT WATER              2042
#                UNSANITARY CONDITION        1949
#                Noise                       1926
#                Noise - Street/Sidewalk      853
# Unspecified    Street Light Condition      1388
#                Illegal Parking             1275
#                Blocked Driveway            1016
#                Noise - Residential          683
#                Noise - Street/Sidewalk      217
#                Street Condition              42
#                Noise                          3
# Name: complaint_type, dtype: int64

# %%
# Consider only the 10 most common overall complaint types.  For the 10 most populous zip codes, how many of each of those 10 types were there in 2017?

import pandas as pd
import numpy as np
from sodapy import Socrata

pd.options.display.max_rows = 5000

token = '9EDniwZuIo69m780HXzBZ7oxK'
client = Socrata('data.cityofnewyork.us', token)
results1 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC')
results2 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=500000)
results3 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=1000000)
results4 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=1500000)
results5 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=2000000)

results_df1 = pd.DataFrame.from_records(results1)
results_df2 = pd.DataFrame.from_records(results2)
results_df3 = pd.DataFrame.from_records(results3)
results_df4 = pd.DataFrame.from_records(results4)
results_df5 = pd.DataFrame.from_records(results5)

combined_df = pd.concat([results_df1, results_df2, results_df3, results_df4, results_df5])
#: Get the top 10 complaints
all_complaints = combined_df[['complaint_type']]
top_tens = all_complaints.complaint_type.value_counts()[:10]
top_ten_complaints = top_tens.to_dict().keys()

#: Clean the zip codes
#remove short zips and all zero zips
all_zips = combined_df.incident_zip.str.slice(0, 5)
short_zips = all_zips.str.len() < 5
zero_zips = all_zips == '00000'
combined_df[short_zips] = np.nan
combined_df[zero_zips] = np.nan
#remaining zips should all be clean
good_zips = combined_df.incident_zip.str.replace(r'[A-Z /.?]','')
good_zips = good_zips.str.slice(0, 5)

#: Sourced from Zipcode-ZCTA-Population-Density-And-Area-Unsorted
#: Filtered out non-NY zips and sorted by descending population count
top_ten_pop_zips = ['11368', '11226', '11373', '11220', '11385', '10467', '10025', '11208', '11236', '11207']

complaints_boroughs = combined_df[['complaint_type', 'incident_zip', 'borough']]
#: Get top 10 complaints
top_complaints_zip = complaints_boroughs[complaints_boroughs.complaint_type.isin(top_ten_complaints)]
#: Get complaints in top 10 zips
top_ten_complaints_and_zips = top_complaints_zip[top_complaints_zip.incident_zip.isin(top_ten_pop_zips)]
complaints_count = top_ten_complaints_and_zips.groupby('incident_zip').complaint_type.value_counts()
print(complaints_count)
# Out:
# incident_zip  complaint_type
# 10025         HEAT/HOT WATER             2357
#               Noise - Residential        2072
#               Noise                      1397
#               Noise - Street/Sidewalk    1223
#               Illegal Parking             736
#               UNSANITARY CONDITION        714
#               Street Condition            628
#               Water System                475
#               Blocked Driveway            125
#               Street Light Condition       21
# 10467         HEAT/HOT WATER             5986
#               Noise - Residential        5758
#               UNSANITARY CONDITION       2191
#               Blocked Driveway           2063
#               Illegal Parking             983
#               Noise - Street/Sidewalk     713
#               Street Condition            612
#               Water System                560
#               Street Light Condition      407
#               Noise                       284
# 11207         Noise - Residential        3051
#               HEAT/HOT WATER             2440
#               Blocked Driveway           2053
#               UNSANITARY CONDITION       1621
#               Illegal Parking            1500
#               Street Condition           1141
#               Street Light Condition      932
#               Water System                755
#               Noise - Street/Sidewalk     558
#               Noise                       199
# 11208         Noise - Residential        2791
#               Blocked Driveway           2743
#               Illegal Parking            2149
#               HEAT/HOT WATER             2025
#               UNSANITARY CONDITION       1339
#               Noise - Street/Sidewalk     825
#               Street Condition            816
#               Water System                710
#               Street Light Condition      566
#               Noise                       188
# 11220         Illegal Parking            2013
#               HEAT/HOT WATER             1598
#               Blocked Driveway           1554
#               Noise - Residential        1521
#               UNSANITARY CONDITION        719
#               Street Condition            690
#               Water System                674
#               Street Light Condition      610
#               Noise - Street/Sidewalk     498
#               Noise                       441
# 11226         HEAT/HOT WATER             7474
#               Noise - Residential        4842
#               UNSANITARY CONDITION       3151
#               Blocked Driveway           2198
#               Noise - Street/Sidewalk    1831
#               Illegal Parking            1074
#               Street Condition            491
#               Noise                       440
#               Water System                400
#               Street Light Condition      202
# 11236         Blocked Driveway           3027
#               Noise - Residential        1924
#               Illegal Parking            1430
#               HEAT/HOT WATER             1130
#               Street Condition           1021
#               Water System                622
#               UNSANITARY CONDITION        562
#               Noise - Street/Sidewalk     201
#               Street Light Condition      180
#               Noise                       108
# 11368         Blocked Driveway           4360
#               Noise - Residential        2457
#               HEAT/HOT WATER             1594
#               Illegal Parking            1251
#               Noise - Street/Sidewalk     684
#               UNSANITARY CONDITION        639
#               Water System                615
#               Street Condition            561
#               Street Light Condition      444
#               Noise                       158
# 11373         HEAT/HOT WATER             3395
#               Blocked Driveway           2626
#               Noise - Residential        1832
#               Illegal Parking            1273
#               UNSANITARY CONDITION        756
#               Street Condition            691
#               Water System                372
#               Street Light Condition      362
#               Noise - Street/Sidewalk     304
#               Noise                       270
# 11385         Illegal Parking            4115
#               Blocked Driveway           3033
#               Noise - Residential        2601
#               HEAT/HOT WATER             1519
#               Water System               1238
#               Street Condition           1232
#               Street Light Condition      791
#               UNSANITARY CONDITION        647
#               Noise - Street/Sidewalk     606
#               Noise                       506
# Name: complaint_type, dtype: int64

# %%
#  Considering all complaint types. Which boroughs are the biggest "complainers" relative to the size of the population in 2017? Meaning, calculate a complaint-index that adjusts for population of the borough.

import pandas as pd
import numpy as np
from sodapy import Socrata

pd.options.display.max_rows = 5000

token = '9EDniwZuIo69m780HXzBZ7oxK'
client = Socrata('data.cityofnewyork.us', token)
results1 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC')
results2 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=500000)
results3 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=1000000)
results4 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=1500000)
results5 = client.get('fhrw-4uyv',  where="created_date between '2017-01-01T00:00:00.000' and '2017-12-31T00:00:00.00'", select="complaint_type, incident_zip, borough", limit=500000, order='created_date ASC', offset=2000000)

results_df1 = pd.DataFrame.from_records(results1)
results_df2 = pd.DataFrame.from_records(results2)
results_df3 = pd.DataFrame.from_records(results3)
results_df4 = pd.DataFrame.from_records(results4)
results_df5 = pd.DataFrame.from_records(results5)

combined_df = pd.concat([results_df1, results_df2, results_df3, results_df4, results_df5])

#: 2017 census population data sourced from https://www1.nyc.gov/site/planning/data-maps/nyc-population/current-future-populations.page
population_by_borough = {'bronx': 1471160, 'brooklyn': 2648771, 'manhattan': 1664727, 'queens': 2358582, 'staten_island': 479458}

complaints_boroughs = combined_df[['complaint_type', 'incident_zip', 'borough']]
#complaints_count = complaints_boroughs.groupby('borough').complaint_type.count()
bx_count = complaints_boroughs[complaints_boroughs['borough'] == 'BRONX'].complaint_type.count() 
bx_index = bx_count / population_by_borough['bronx']
bk_count = complaints_boroughs[complaints_boroughs['borough'] == 'BROOKLYN'].complaint_type.count()
bk_index = bk_count / population_by_borough['brooklyn']
man_count = complaints_boroughs[complaints_boroughs['borough'] == 'MANHATTAN'].complaint_type.count()
man_index = man_count / population_by_borough['manhattan']
qns_count = complaints_boroughs[complaints_boroughs['borough'] == 'QUEENS'].complaint_type.count()
qns_index = qns_count / population_by_borough['queens']
si_count = complaints_boroughs[complaints_boroughs['borough'] == 'STATEN ISLAND'].complaint_type.count() 
si_index = si_count / population_by_borough['staten_island']

data = {
    'Borough': ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND'], 
    'Uncorrected Count': [bx_count, bk_count, man_count, qns_count, si_count], 
    'Complaint Index': [bx_index, bk_index, man_index, qns_index, si_index],
    'Corrected Count': [(bx_count * bx_index), (bk_count * bk_index), (man_count * man_index), (qns_count * qns_index), (si_count * si_index)]    
}
df = pd.DataFrame(data)
print(df)
# Out:
#          Borough  Complaint Index  Corrected Count  Uncorrected Count
# 0          BRONX         0.304162    136103.684060             447471
# 1       BROOKLYN         0.286582    217541.504381             759090
# 2      MANHATTAN         0.287744    137834.208405             479016
# 3         QUEENS         0.248339    145459.131794             585728
# 4  STATEN ISLAND         0.264029     33423.743646             126591
